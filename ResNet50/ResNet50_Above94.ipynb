# %%
# ============================================================
# ADVANCED RESNET50 PIPELINE
# CHEST X-RAY PNEUMONIA CLASSIFICATION
# SMALL DATASET OPTIMIZED
# ============================================================

# ============================================================
# 1. INSTALLS
# ============================================================
# !pip install opencv-python -q

# ============================================================
# 2. Imports
# ============================================================
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.applications import ResNet50

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    f1_score
)

from sklearn.utils.class_weight import compute_class_weight

# ============================================================
# 3. Config
# ============================================================
from google.colab import drive

drive.mount('/content/drive')

data_dir = 'yourdirectory'

IMG_SIZE = (224,224)

BATCH_SIZE = 16

EPOCHS = 50

SEED = 42

DATASET_PERCENTAGE = 1

# ============================================================
# 4. Load datasets
# ============================================================

# TRAIN
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir + "/train",
    validation_split=0.2,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary'
)

# VALIDATION
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir + "/train",
    validation_split=0.2,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary'
)

# TEST
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir + "/test",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='binary'
)


# ============================================================
# 5. Compute class weights
# ============================================================
y_train = []

for images, labels in train_ds:
    y_train.extend(labels.numpy().flatten())

y_train = np.array(y_train)

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)

class_weights = {
    0: class_weights[0],
    1: class_weights[1]
}

print("\nCLASS WEIGHTS")
print(class_weights)

# ============================================================
# 6. Performance optimization
# ============================================================
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)
test_ds = test_ds.cache().prefetch(AUTOTUNE)

# ============================================================
# 7. Data augmentation
# ============================================================
data_augmentation = tf.keras.Sequential([

    layers.RandomFlip("horizontal"),

    layers.RandomRotation(0.08),

    layers.RandomZoom(0.08),

    layers.RandomContrast(0.1)

])

# ============================================================
# 8. Build ResNet50
# ============================================================
def build_resnet50():

    # ========================================================
    # Backbone
    # ========================================================
    base_model = ResNet50(

        include_top=False,

        weights='imagenet',

        input_shape=(224,224,3)
    )

    # ========================================================
    # Fine tuning
    # ========================================================
    base_model.trainable = True

    for layer in base_model.layers[:-120]:
        layer.trainable = False

    # ========================================================
    # Input
    # ========================================================
    inputs = tf.keras.Input(
        shape=(224,224,3)
    )

    # Augmentation
    x = data_augmentation(inputs)

    # Preprocessing
    x = tf.keras.applications.resnet.preprocess_input(x)

    # Backbone
    x = base_model(
        x,
        training=False
    )

    # ========================================================
    # Classification head
    # ========================================================
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dropout(0.4)(x)

    x = layers.Dense(
        256,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.001)
    )(x)

    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(
        1,
        activation='sigmoid'
    )(x)

    model = tf.keras.Model(
        inputs,
        outputs
    )

    return model

# ============================================================
# 9. Create model
# ============================================================
model = build_resnet50()

model.summary()

# ============================================================
# 10. Cosine decay LR
# ============================================================
steps_per_epoch = tf.data.experimental.cardinality(train_ds).numpy()

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(

    initial_learning_rate=1e-4,

    decay_steps=steps_per_epoch * EPOCHS
)

# ============================================================
# 11. Compile
# ============================================================
model.compile(

    optimizer=tf.keras.optimizers.Adam(
        learning_rate=lr_schedule
    ),

    loss=tf.keras.losses.BinaryFocalCrossentropy(

        gamma=2.0,

        apply_class_balancing=True
    ),

    metrics=[

        'accuracy',

        tf.keras.metrics.Precision(
            name='precision'
        ),

        tf.keras.metrics.Recall(
            name='recall'
        ),

        tf.keras.metrics.AUC(
            name='auc'
        )
    ]
)

# ============================================================
# 12. Callbacks
# ============================================================
callbacks = [

    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True
    ),

    tf.keras.callbacks.ModelCheckpoint(
        'best_resnet50.keras',
        monitor='val_loss',
        save_best_only=True
    )
]

# ============================================================
# 13. Train
# ============================================================
history = model.fit(

    train_ds,

    validation_data=val_ds,

    epochs=EPOCHS,

    callbacks=callbacks,

    class_weight=class_weights
)

# ============================================================
# 14. Plot history
# ============================================================
def plot_history(history):

    # Accuracy
    plt.figure(figsize=(8,5))

    plt.plot(
        history.history['accuracy'],
        label='Train Accuracy'
    )

    plt.plot(
        history.history['val_accuracy'],
        label='Validation Accuracy'
    )

    plt.title('ResNet50 Accuracy')

    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')

    plt.legend()

    plt.show()

    # Loss
    plt.figure(figsize=(8,5))

    plt.plot(
        history.history['loss'],
        label='Train Loss'
    )

    plt.plot(
        history.history['val_loss'],
        label='Validation Loss'
    )

    plt.title('ResNet50 Loss')

    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    plt.legend()

    plt.show()

plot_history(history)

# ============================================================
# 15. TEST TIME AUGMENTATION
# ============================================================
def tta_predict(model, images, n=2):

    preds = []

    for _ in range(n):

        augmented = data_augmentation(
            images,
            training=True
        )

        pred = model.predict(
            augmented,
            verbose=0
        )

        preds.append(pred)

    return np.mean(
        preds,
        axis=0
    )

# ============================================================
# 16. Predictions
# ============================================================
def get_predictions(model, dataset):

    y_true = []
    y_pred = []

    for x, y in dataset:

        preds = tta_predict(
            model,
            x,
            n=5
        )

        y_true.extend(y.numpy())

        y_pred.extend(
            preds.flatten()
        )

    return np.array(y_true), np.array(y_pred)

y_true, y_pred = get_predictions(
    model,
    test_ds
)

# ============================================================
# 17. Threshold optimization
# ============================================================
thresholds = np.arange(
    0.1,
    0.9,
    0.01
)

best_threshold = 0
best_f1 = 0

for t in thresholds:

    preds = (
        y_pred > t
    ).astype(int)

    f1 = f1_score(
        y_true,
        preds
    )

    if f1 > best_f1:

        best_f1 = f1

        best_threshold = t

print("\nBEST THRESHOLD:", best_threshold)
print("BEST F1:", best_f1)

# ============================================================
# 18. Final predictions
# ============================================================
y_pred_bin = (
    y_pred > best_threshold
).astype(int)

# ============================================================
# 19. Classification report
# ============================================================
print("\nCLASSIFICATION REPORT\n")

print(
    classification_report(
        y_true,
        y_pred_bin,
        target_names=[
            'NORMAL',
            'PNEUMONIA'
        ]
    )
)

# ============================================================
# 20. Confusion matrix
# ============================================================
cm = confusion_matrix(
    y_true,
    y_pred_bin
)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=[
        'NORMAL',
        'PNEUMONIA'
    ],
    yticklabels=[
        'NORMAL',
        'PNEUMONIA'
    ]
)

plt.title(
    'ResNet50 Confusion Matrix'
)

plt.xlabel('Predicted')
plt.ylabel('True')

plt.show()

# ============================================================
# 21. ROC Curve
# ============================================================
fpr, tpr, thresholds = roc_curve(
    y_true,
    y_pred
)

roc_auc = auc(
    fpr,
    tpr
)

plt.figure(figsize=(6,5))

plt.plot(
    fpr,
    tpr,
    label=f'AUC = {roc_auc:.3f}'
)

plt.plot([0,1], [0,1], '--')

plt.title('ResNet50 ROC Curve')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.legend()

plt.show()

print(f"\nAUC SCORE: {roc_auc:.4f}")
# Out:
# Mounted at /content/drive
# Found 5232 files belonging to 2 classes.
# Using 4186 files for training.
# Found 5232 files belonging to 2 classes.
# Using 1046 files for validation.
# Found 624 files belonging to 2 classes.
#
# CLASS WEIGHTS
# {0: np.float64(1.9061930783242258), 1: np.float64(0.6777849740932642)}
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 224, 224,  │          0 │ input_layer_1[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 224, 224)  │          0 │ sequential[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack (Stack)       │ (None, 224, 224,  │          0 │ get_item[0][0],   │
# │                     │ 3)                │            │ get_item_1[0][0], │
# │                     │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 224, 224,  │          0 │ stack[0][0]       │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 7, 7,      │ 23,587,712 │ add[0][0]         │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    524,544 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        257 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,112,513 (91.98 MB)
#  Trainable params: 23,238,401 (88.65 MB)
#  Non-trainable params: 874,112 (3.33 MB)
# Epoch 1/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2378s 9s/step - accuracy: 0.8653 - auc: 0.9601 - loss: 0.4490 - precision: 0.9809 - recall: 0.8335 - val_accuracy: 0.9541 - val_auc: 0.9947 - val_loss: 0.3915 - val_precision: 0.9973 - val_recall: 0.9421
# Epoch 2/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2251s 9s/step - accuracy: 0.9326 - auc: 0.9898 - loss: 0.3596 - precision: 0.9947 - recall: 0.9135 - val_accuracy: 0.8872 - val_auc: 0.9913 - val_loss: 0.3530 - val_precision: 0.9985 - val_recall: 0.8528
# Epoch 3/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2253s 9s/step - accuracy: 0.9510 - auc: 0.9938 - loss: 0.2979 - precision: 0.9959 - recall: 0.9375 - val_accuracy: 0.9187 - val_auc: 0.9979 - val_loss: 0.2745 - val_precision: 1.0000 - val_recall: 0.8931
# Epoch 4/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2238s 9s/step - accuracy: 0.9551 - auc: 0.9957 - loss: 0.2477 - precision: 0.9952 - recall: 0.9437 - val_accuracy: 0.8901 - val_auc: 0.9990 - val_loss: 0.2415 - val_precision: 1.0000 - val_recall: 0.8553
# Epoch 5/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2229s 8s/step - accuracy: 0.9728 - auc: 0.9982 - loss: 0.2032 - precision: 0.9980 - recall: 0.9650 - val_accuracy: 0.9713 - val_auc: 0.9994 - val_loss: 0.1848 - val_precision: 1.0000 - val_recall: 0.9623
# Epoch 6/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2265s 9s/step - accuracy: 0.9735 - auc: 0.9978 - loss: 0.1678 - precision: 0.9983 - recall: 0.9657 - val_accuracy: 0.9388 - val_auc: 0.9995 - val_loss: 0.1583 - val_precision: 1.0000 - val_recall: 0.9195
# Epoch 7/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2263s 9s/step - accuracy: 0.9728 - auc: 0.9982 - loss: 0.1377 - precision: 0.9980 - recall: 0.9650 - val_accuracy: 0.9541 - val_auc: 0.9990 - val_loss: 0.1271 - val_precision: 1.0000 - val_recall: 0.9396
# Epoch 8/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2278s 9s/step - accuracy: 0.9835 - auc: 0.9991 - loss: 0.1102 - precision: 0.9987 - recall: 0.9790 - val_accuracy: 0.9704 - val_auc: 0.9993 - val_loss: 0.1010 - val_precision: 1.0000 - val_recall: 0.9610
# Epoch 9/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2234s 9s/step - accuracy: 0.9873 - auc: 0.9995 - loss: 0.0881 - precision: 0.9984 - recall: 0.9845 - val_accuracy: 0.9426 - val_auc: 0.9995 - val_loss: 0.0900 - val_precision: 1.0000 - val_recall: 0.9245
# Epoch 10/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2177s 8s/step - accuracy: 0.9845 - auc: 0.9993 - loss: 0.0706 - precision: 0.9987 - recall: 0.9802 - val_accuracy: 0.9904 - val_auc: 0.9994 - val_loss: 0.0634 - val_precision: 0.9962 - val_recall: 0.9912
# Epoch 11/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2170s 8s/step - accuracy: 0.9795 - auc: 0.9991 - loss: 0.0572 - precision: 0.9980 - recall: 0.9741 - val_accuracy: 0.9751 - val_auc: 0.9997 - val_loss: 0.0528 - val_precision: 1.0000 - val_recall: 0.9673
# Epoch 12/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2159s 8s/step - accuracy: 0.9697 - auc: 0.9976 - loss: 0.0491 - precision: 0.9976 - recall: 0.9611 - val_accuracy: 0.9790 - val_auc: 0.9995 - val_loss: 0.0415 - val_precision: 0.9987 - val_recall: 0.9736
# Epoch 13/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2226s 8s/step - accuracy: 0.9792 - auc: 0.9986 - loss: 0.0383 - precision: 0.9987 - recall: 0.9731 - val_accuracy: 0.9876 - val_auc: 0.9991 - val_loss: 0.0334 - val_precision: 0.9975 - val_recall: 0.9862
# Epoch 14/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2228s 9s/step - accuracy: 0.9766 - auc: 0.9985 - loss: 0.0317 - precision: 0.9987 - recall: 0.9696 - val_accuracy: 0.9522 - val_auc: 0.9987 - val_loss: 0.0332 - val_precision: 1.0000 - val_recall: 0.9371
# Epoch 15/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2204s 8s/step - accuracy: 0.9830 - auc: 0.9991 - loss: 0.0250 - precision: 0.9990 - recall: 0.9780 - val_accuracy: 0.9407 - val_auc: 0.9988 - val_loss: 0.0429 - val_precision: 1.0000 - val_recall: 0.9220
# Epoch 16/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2284s 9s/step - accuracy: 0.9871 - auc: 0.9995 - loss: 0.0201 - precision: 0.9990 - recall: 0.9835 - val_accuracy: 0.9732 - val_auc: 0.9996 - val_loss: 0.0228 - val_precision: 1.0000 - val_recall: 0.9648
# Epoch 17/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2251s 9s/step - accuracy: 0.9912 - auc: 0.9998 - loss: 0.0156 - precision: 0.9997 - recall: 0.9883 - val_accuracy: 0.9847 - val_auc: 0.9992 - val_loss: 0.0163 - val_precision: 0.9987 - val_recall: 0.9811
# Epoch 18/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2316s 9s/step - accuracy: 0.9916 - auc: 0.9998 - loss: 0.0128 - precision: 0.9997 - recall: 0.9890 - val_accuracy: 0.9771 - val_auc: 0.9991 - val_loss: 0.0189 - val_precision: 1.0000 - val_recall: 0.9698
# Epoch 19/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2127s 8s/step - accuracy: 0.9919 - auc: 0.9990 - loss: 0.0126 - precision: 0.9990 - recall: 0.9900 - val_accuracy: 0.9493 - val_auc: 0.9991 - val_loss: 0.0261 - val_precision: 1.0000 - val_recall: 0.9333
# Epoch 20/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2123s 8s/step - accuracy: 0.9847 - auc: 0.9992 - loss: 0.0109 - precision: 0.9977 - recall: 0.9815 - val_accuracy: 0.9685 - val_auc: 0.9993 - val_loss: 0.0144 - val_precision: 1.0000 - val_recall: 0.9585
# Epoch 21/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2094s 8s/step - accuracy: 0.9854 - auc: 0.9993 - loss: 0.0098 - precision: 0.9990 - recall: 0.9812 - val_accuracy: 0.9618 - val_auc: 0.9995 - val_loss: 0.0174 - val_precision: 1.0000 - val_recall: 0.9497
# Epoch 22/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2126s 8s/step - accuracy: 0.9926 - auc: 0.9999 - loss: 0.0068 - precision: 0.9997 - recall: 0.9903 - val_accuracy: 0.9723 - val_auc: 0.9993 - val_loss: 0.0137 - val_precision: 1.0000 - val_recall: 0.9635
# Epoch 23/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2145s 8s/step - accuracy: 0.9909 - auc: 0.9996 - loss: 0.0064 - precision: 0.9993 - recall: 0.9883 - val_accuracy: 0.9761 - val_auc: 0.9995 - val_loss: 0.0107 - val_precision: 1.0000 - val_recall: 0.9686
# Epoch 24/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2068s 8s/step - accuracy: 0.9931 - auc: 0.9997 - loss: 0.0059 - precision: 0.9993 - recall: 0.9913 - val_accuracy: 0.9207 - val_auc: 0.9995 - val_loss: 0.0273 - val_precision: 1.0000 - val_recall: 0.8956
# Epoch 25/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2117s 8s/step - accuracy: 0.9816 - auc: 0.9994 - loss: 0.0070 - precision: 0.9987 - recall: 0.9764 - val_accuracy: 0.9723 - val_auc: 0.9994 - val_loss: 0.0108 - val_precision: 1.0000 - val_recall: 0.9635
# Epoch 26/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2070s 8s/step - accuracy: 0.9912 - auc: 0.9997 - loss: 0.0048 - precision: 0.9990 - recall: 0.9890 - val_accuracy: 0.9857 - val_auc: 0.9989 - val_loss: 0.0071 - val_precision: 1.0000 - val_recall: 0.9811
# Epoch 27/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2171s 8s/step - accuracy: 0.9959 - auc: 0.9998 - loss: 0.0041 - precision: 0.9997 - recall: 0.9948 - val_accuracy: 0.9799 - val_auc: 0.9997 - val_loss: 0.0074 - val_precision: 1.0000 - val_recall: 0.9736
# Epoch 28/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2212s 8s/step - accuracy: 0.9940 - auc: 0.9999 - loss: 0.0034 - precision: 0.9997 - recall: 0.9922 - val_accuracy: 0.9751 - val_auc: 0.9996 - val_loss: 0.0096 - val_precision: 1.0000 - val_recall: 0.9673
# Epoch 29/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2243s 9s/step - accuracy: 0.9950 - auc: 0.9999 - loss: 0.0032 - precision: 0.9993 - recall: 0.9938 - val_accuracy: 0.9455 - val_auc: 0.9993 - val_loss: 0.0206 - val_precision: 1.0000 - val_recall: 0.9283
# Epoch 30/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2369s 9s/step - accuracy: 0.9969 - auc: 1.0000 - loss: 0.0024 - precision: 1.0000 - recall: 0.9958 - val_accuracy: 0.9541 - val_auc: 0.9986 - val_loss: 0.0208 - val_precision: 1.0000 - val_recall: 0.9396
# Epoch 31/50
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 2341s 9s/step - accuracy: 0.9964 - auc: 1.0000 - loss: 0.0023 - precision: 1.0000 - recall: 0.9951 - val_accuracy: 0.9694 - val_auc: 0.9995 - val_loss: 0.0123 - val_precision: 1.0000 - val_recall: 0.9597
# BEST THRESHOLD: 0.8799999999999996
# BEST F1: 0.9540816326530612
#
# CLASSIFICATION REPORT
#
#               precision    recall  f1-score   support
#
#       NORMAL       0.93      0.91      0.92       234
#    PNEUMONIA       0.95      0.96      0.95       390
#
#     accuracy                           0.94       624
#    macro avg       0.94      0.94      0.94       624
# weighted avg       0.94      0.94      0.94       624
# AUC SCORE: 0.9813
